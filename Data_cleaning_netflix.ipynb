# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('netflix_titles.csv')
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                   NaN            NaN
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#               date_added  release_year rating   duration  \
# 0     September 25, 2021          2020  PG-13     90 min
# 1     September 24, 2021          2021  TV-MA  2 Seasons
# 2     September 24, 2021          2021  TV-MA   1 Season
# 3     September 24, 2021          2021  TV-MA   1 Season
# 4     September 24, 2021          2021  TV-MA  2 Seasons
# ...                  ...           ...    ...        ...
# 8802   November 20, 2019          2007      R    158 min
# 8803        July 1, 2019          2018  TV-Y7  2 Seasons
# 8804    November 1, 2019          2009      R     88 min
# 8805    January 11, 2020          2006     PG     88 min
# 8806       March 2, 2019          2015  TV-14    111 min
#
#                                               listed_in  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8802                     Cult Movies, Dramas, Thrillers
# 8803             Kids' TV, Korean TV Shows, TV Comedies
# 8804                            Comedies, Horror Movies
# 8805                 Children & Family Movies, Comedies
# 8806     Dramas, International Movies, Music & Musicals
#
#                                             description
# 0     As her father nears the end of his life, filmm...
# 1     After crossing paths at a party, a Cape Town t...
# 2     To protect his family from a powerful drug lor...
# 3     Feuds, flirtations and toilet talk go down amo...
# 4     In a city of coaching centers known to train I...
# ...                                                 ...
# 8802  A political cartoonist, a crime reporter and a...
# 8803  While living alone in a spooky town, a young g...
# 8804  Looking to survive in a world taken over by zo...
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...
#
# [8807 rows x 12 columns]

# %%
df.sample(5)
# Out:
#      show_id     type                            title  \
# 1357   s1358    Movie                            Rocks
# 8575   s8576  TV Show                  This Is My Love
# 1027   s1028    Movie                     Crimson Peak
# 4788   s4789    Movie     Katt Williams: Kattpacalypse
# 4217   s4218    Movie  Monty Python and the Holy Grail
#
#                         director  \
# 1357                Sarah Gavron
# 8575                         NaN
# 1027          Guillermo del Toro
# 4788                Marcus Raboy
# 4217  Terry Gilliam, Terry Jones
#
#                                                    cast  \
# 1357  Bukky Bakray, Kosar Ali, D'angelou Osei Kissie...
# 8575  Jin-mo Joo, Sa-rang Kim, Junior, Ja-in Lee, Su...
# 1027  Mia Wasikowska, Jessica Chastain, Tom Hiddlest...
# 4788                                      Katt Williams
# 4217  Graham Chapman, John Cleese, Eric Idle, Terry ...
#
#                             country        date_added  release_year rating  \
# 1357                 United Kingdom  February 1, 2021          2019  TV-MA
# 8575                    South Korea      May 22, 2017          2015  TV-14
# 1027  Canada, United States, Mexico    April 16, 2021          2015      R
# 4788                  United States      July 3, 2018          2012  TV-MA
# 4217                 United Kingdom   January 2, 2019          1975     PG
#
#       duration                                          listed_in  \
# 1357    93 min                                             Dramas
# 8575  1 Season  International TV Shows, Korean TV Shows, Roman...
# 1027   119 min   Horror Movies, Romantic Movies, Sci-Fi & Fantasy
# 4788    61 min                                    Stand-Up Comedy
# 4217    92 min       Action & Adventure, Classic Movies, Comedies
#
#                                             description
# 1357  Following her mother's abrupt departure, a dyn...
# 8575  A renowned actor who is still pining over the ...
# 1027  After marrying a mysterious British aristocrat...
# 4788  Urban comic Katt Williams ushers in Kattpacaly...
# 4217  The Monty Python comedy clan skewers King Arth...

# %%
df.sample() # if no number is mentioned within bracket then displays only one row
# Out:
#      show_id   type       title      director  \
# 2389   s2390  Movie  Asura Guru  A. Raajdheep
#
#                                                    cast country  \
# 2389  Vikram Prabhu, Subbaraju, Mahima Nambiar, Yogi...   India
#
#          date_added  release_year rating duration  \
# 2389  June 13, 2020          2020  TV-14  117 min
#
#                          listed_in  \
# 2389  Dramas, International Movies
#
#                                             description
# 2389  For a tech-savvy thief, elaborate robberies an...

# %%
df.drop(["show_id","description"],axis=1,inplace=True)

# %%
df.sample(5)
# Out:
#          type                                     title       director  \
# 3187  TV Show                               Nightflyers            NaN
# 398     Movie               Kingdom: Ashin of the North  Kim Seong-hun
# 8357  TV Show                          The Inbetweeners            NaN
# 6124    Movie  Alpha and Omega 2: A Howl-iday Adventure   Richard Rich
# 6657    Movie                             Earth to Echo     Dave Green
#
#                                                    cast         country  \
# 3187  Eoin Macken, David Ajala, Jodie Turner-Smith, ...   United States
# 398   Gianna Jun, Park Byung-eun, Kim Si-a, Kim Roi-...             NaN
# 8357  Simon Bird, James Buckley, Blake Harrison, Joe...  United Kingdom
# 6124  Ben Diskin, Kate Higgins, Blackie Rose, Lindsa...   United States
# 6657  Teo Halm, Astro, Reese Hartwig, Ella Wahlested...   United States
#
#             date_added  release_year rating   duration  \
# 3187  December 2, 2019          2018  TV-MA   1 Season
# 398      July 23, 2021          2021  TV-MA     94 min
# 8357   January 1, 2018          2010  TV-MA  3 Seasons
# 6124   October 1, 2019          2013   TV-G     45 min
# 6657   October 1, 2019          2014     PG     91 min
#
#                                            listed_in
# 3187    TV Horror, TV Mysteries, TV Sci-Fi & Fantasy
# 398   Horror Movies, International Movies, Thrillers
# 8357                   British TV Shows, TV Comedies
# 6124                        Children & Family Movies
# 6657      Children & Family Movies, Sci-Fi & Fantasy

# %%
df.shape
# Out:
# (8807, 10)

# %%
df.size
# Out:
# 88070

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8807, step=1)

# %%
df.columns
# Out:
# Index(['type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          8807 non-null   object
#  1   title         8807 non-null   object
#  2   director      6173 non-null   object
#  3   cast          7982 non-null   object
#  4   country       7976 non-null   object
#  5   date_added    8797 non-null   object
#  6   release_year  8807 non-null   int64
#  7   rating        8803 non-null   object
#  8   duration      8804 non-null   object
#  9   listed_in     8807 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 688.2+ KB

# %%
df.isna().sum()
# Out:
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# dtype: int64

# %%
df["country"].value_counts().head(3)
# Out:
# country
# United States     2818
# India              972
# United Kingdom     419
# Name: count, dtype: int64

# %%
mode_country=df["country"].mode()[0]

# %%
mode_country
# Out:
# 'United States'

# %%
df["country"]=df["country"].fillna(mode_country)

# %%
df["country"].isna().sum()
# Out:
# np.int64(0)

# %%
df["date_added"].value_counts().head(3)
# Out:
# date_added
# January 1, 2020     109
# November 1, 2019     89
# March 1, 2018        75
# Name: count, dtype: int64

# %%
mode_date=df["date_added"].mode()[0]

# %%
mode_date
# Out:
# 'January 1, 2020'

# %%
df["date_added"]=df["date_added"].fillna(mode_date)

# %%
df["date_added"].isna().sum()
# Out:
# np.int64(0)

# %%
mode_rating=df["rating"].mode()[0]

# %%
mode_rating
# Out:
# 'TV-MA'

# %%
df["rating"]=df["rating"].fillna(mode_rating)

# %%
df["rating"].isna().sum()
# Out:
# np.int64(0)

# %%
mode_duration=df["duration"].mode()[0]

# %%
mode_duration
# Out:
# '1 Season'

# %%
df["duration"]=df["duration"].fillna(mode_duration)

# %%
df["duration"].isna().sum()
# Out:
# np.int64(0)

# %%
df["director"]=df["director"].fillna("Not Mentioned")

# %%
df["director"].isna().sum()
# Out:
# np.int64(0)

# %%
df["cast"]=df["cast"].fillna("Not Mentioned")

# %%
df["cast"].isna().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          8807 non-null   object
#  1   title         8807 non-null   object
#  2   director      8807 non-null   object
#  3   cast          8807 non-null   object
#  4   country       8807 non-null   object
#  5   date_added    8807 non-null   object
#  6   release_year  8807 non-null   int64
#  7   rating        8807 non-null   object
#  8   duration      8807 non-null   object
#  9   listed_in     8807 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 688.2+ KB

# %%
df["rating"].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR',
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
df= df[~df["rating"].str.contains("min")]

# %%
df["date_added"].unique()
# Out:
# array(['September 25, 2021', 'September 24, 2021', 'September 23, 2021',
#        ..., 'December 6, 2018', 'March 9, 2016', 'January 11, 2020'],
#       dtype=object)

# %%
df["date_added"]=df["date_added"].str.replace(",","")
# Out:
# C:\Users\rohit\AppData\Local\Temp\ipykernel_43768\2649166716.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["date_added"]=df["date_added"].str.replace(",","")

# %%
df["date_added"].unique()
# Out:
# array(['September 25 2021', 'September 24 2021', 'September 23 2021', ...,
#        'December 6 2018', 'March 9 2016', 'January 11 2020'], dtype=object)

# %%
df["date_added"] = pd.to_datetime(df["date_added"], format="mixed")
# Out:
# C:\Users\rohit\AppData\Local\Temp\ipykernel_43768\498004367.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["date_added"] = pd.to_datetime(df["date_added"], format="mixed")

# %%
df["date_added"].unique()
# Out:
# <DatetimeArray>
# ['2021-09-25 00:00:00', '2021-09-24 00:00:00', '2021-09-23 00:00:00',
#  '2021-09-22 00:00:00', '2021-09-21 00:00:00', '2021-09-20 00:00:00',
#  '2021-09-19 00:00:00', '2021-09-17 00:00:00', '2021-09-16 00:00:00',
#  '2021-09-15 00:00:00',
#  ...
#  '2018-09-27 00:00:00', '2017-03-23 00:00:00', '2016-12-25 00:00:00',
#  '2016-11-30 00:00:00', '2017-10-23 00:00:00', '2017-11-04 00:00:00',
#  '2015-08-05 00:00:00', '2018-12-06 00:00:00', '2016-03-09 00:00:00',
#  '2020-01-11 00:00:00']
# Length: 1714, dtype: datetime64[ns]

# %%
df["year"]=df["date_added"].dt.year
# Out:
# C:\Users\rohit\AppData\Local\Temp\ipykernel_43768\1025263937.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["year"]=df["date_added"].dt.year

# %%
df["month"]=df["date_added"].dt.month
# Out:
# C:\Users\rohit\AppData\Local\Temp\ipykernel_43768\4265263075.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["month"]=df["date_added"].dt.month

# %%
df["day"]=df["date_added"].dt.day
# Out:
# C:\Users\rohit\AppData\Local\Temp\ipykernel_43768\292946900.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["day"]=df["date_added"].dt.day

# %%
df.sample
